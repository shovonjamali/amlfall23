# %% [markdown]
# # Exercise - building neural networks using TensorFlow
#
# 1. Start by replicating the neural network in the slides (not the training - building it and using the method $\texttt{.summary}$. You can see the number of parameters in each layer. Can you relate this to the number of features, the number of hidden nodes, and the number of output nodes?
# 2. Do you believe the model has too many parameters? Too few? Try to change the number of parameters (in whichever direction you believe is best) and then train the model on the breast cancer data. Is your model better than the one in the slides? **Bonus**: try also to change the number of epochs you train for, as well as anything else you might want to experiment with.
#
# **Note**: The number of epochs is the number of times the neural network sees each observation. In the above example, each observation is shown 5 times.
#
# **See slides for more details!**

# %% [markdown]
# # Exercise 1
#
# Start by replicating the neural network in the slides (not the training - building it and using the method $\texttt{.summary}$. You can see the number of parameters in each layer. Can you relate this to the number of features, the number of hidden nodes, and the number of output nodes?

# %%
import tensorflow as tf

my_nn = tf.keras.models.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(30,)), # input shape required in the first layer
    tf.keras.layers.Dense(128, activation='relu'), # map 64 to 128 features and apply ReLU
    tf.keras.layers.Dense(2, activation='softmax'), # softmax is used for classification
    ])

my_nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                1984
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dense_2 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 10,562
# Trainable params: 10,562
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Exercise 2
#
# Do you believe the model has too many parameters? Too few? Try to change the number of parameters (in whichever direction you believe is best) and then train the model on the breast cancer data. Is your model better than the one in the slides? **Bonus**: try also to change the number of epochs you train for, as well as anything else you might want to experiment with.

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# Use the `load_breast_cancer` function to construct your dataset
x, y = load_breast_cancer(return_X_y=True)

# Use `train_test_split` to split your data into a train and a test set.
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

scaler = MinMaxScaler() #StandardScaler()
z_train = scaler.fit_transform(x_train)
z_test = scaler.transform(x_test)

# %%
# Build your own, new neural network here
import tensorflow as tf
first = tf.keras.models.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(30,)), # input shape required in the first layer
    tf.keras.layers.Dense(128, activation='relu'), # map 64 to 128 features and apply ReLU
    tf.keras.layers.Dense(128, activation='relu'), # map 128 to 128 features and apply ReLU
    tf.keras.layers.Dense(64, activation='relu'), # map 128 to 64 features and apply ReLU
    tf.keras.layers.Dense(2, activation='softmax'), # softmax is used for classification
    ])
first.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 64)                1984
#
#  dense_4 (Dense)             (None, 128)               8320
#
#  dense_5 (Dense)             (None, 128)               16512
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dense_7 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 35,202
# Trainable params: 35,202
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile it, train it, and evaluate it
first.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'],
    )
first.fit(z_train,y_train,epochs=8)

loss, accuracy = first.evaluate(z_test, y_test)

print(f'\nOut first neural network managed {round(accuracy * 100, 2)}% accuracy.')
# Out:
# Epoch 1/8
# 15/15 [==============================] - 3s 3ms/step - loss: 0.6883 - accuracy: 0.6242
# Epoch 2/8
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6695 - accuracy: 0.8330
# Epoch 3/8
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6523 - accuracy: 0.8000
# Epoch 4/8
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6360 - accuracy: 0.7231
# Epoch 5/8
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6213 - accuracy: 0.7604
# Epoch 6/8
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6072 - accuracy: 0.7714
# Epoch 7/8
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5927 - accuracy: 0.7780
# Epoch 8/8
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5775 - accuracy: 0.8462
# 4/4 [==============================] - 0s 2ms/step - loss: 0.5647 - accuracy: 0.8333
#
# Out first neural network managed 83.33% accuracy.

# %%
# And now try some other stuff, such as training for another number of epochs
first.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'],
    )
first.fit(z_train,y_train,epochs=80)

loss, accuracy = first.evaluate(z_test, y_test)

print(f'\nOut second neural network managed {round(accuracy * 100, 2)}% accuracy.')
# Out:
# Epoch 1/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0127 - accuracy: 0.9956
# Epoch 2/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0116 - accuracy: 0.9978
# Epoch 3/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 0.9934
# Epoch 4/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0075 - accuracy: 0.9978
# Epoch 5/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0399 - accuracy: 0.9824
# Epoch 6/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0228 - accuracy: 0.9912
# Epoch 7/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0636 - accuracy: 0.9780
# Epoch 8/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0194 - accuracy: 0.9934
# Epoch 9/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0109 - accuracy: 0.9956
# Epoch 10/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 11/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 12/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 13/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 14/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 15/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 16/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 17/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 18/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 19/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 20/80
# 15/15 [==============================] - 0s 2ms/step - loss: 9.5022e-04 - accuracy: 1.0000
# Epoch 21/80
# 15/15 [==============================] - 0s 2ms/step - loss: 8.8116e-04 - accuracy: 1.0000
# Epoch 22/80
# 15/15 [==============================] - 0s 2ms/step - loss: 7.5617e-04 - accuracy: 1.0000
# Epoch 23/80
# 15/15 [==============================] - 0s 2ms/step - loss: 6.6573e-04 - accuracy: 1.0000
# Epoch 24/80
# 15/15 [==============================] - 0s 2ms/step - loss: 6.2822e-04 - accuracy: 1.0000
# Epoch 25/80
# 15/15 [==============================] - 0s 2ms/step - loss: 6.0556e-04 - accuracy: 1.0000
# Epoch 26/80
# 15/15 [==============================] - 0s 2ms/step - loss: 5.5619e-04 - accuracy: 1.0000
# Epoch 27/80
# 15/15 [==============================] - 0s 2ms/step - loss: 5.3483e-04 - accuracy: 1.0000
# Epoch 28/80
# 15/15 [==============================] - 0s 2ms/step - loss: 5.0056e-04 - accuracy: 1.0000
# Epoch 29/80
# 15/15 [==============================] - 0s 2ms/step - loss: 4.4951e-04 - accuracy: 1.0000
# Epoch 30/80
# 15/15 [==============================] - 0s 3ms/step - loss: 4.1656e-04 - accuracy: 1.0000
# Epoch 31/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 32/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0182 - accuracy: 0.9956
# Epoch 33/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2424 - accuracy: 0.9451
# Epoch 34/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0905 - accuracy: 0.9626
# Epoch 35/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0332 - accuracy: 0.9956
# Epoch 36/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 0.9934
# Epoch 37/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 38/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 39/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 40/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 41/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 42/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 43/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 44/80
# 15/15 [==============================] - 0s 2ms/step - loss: 8.6408e-04 - accuracy: 1.0000
# Epoch 45/80
# 15/15 [==============================] - 0s 2ms/step - loss: 9.4430e-04 - accuracy: 1.0000
# Epoch 46/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0105 - accuracy: 0.9956
# Epoch 47/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0056 - accuracy: 0.9978
# Epoch 48/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0032 - accuracy: 0.9978
# Epoch 49/80
# 15/15 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 50/80
# 15/15 [==============================] - 0s 2ms/step - loss: 7.6449e-04 - accuracy: 1.0000
# Epoch 51/80
# 15/15 [==============================] - 0s 2ms/step - loss: 4.0077e-04 - accuracy: 1.0000
# Epoch 52/80
# 15/15 [==============================] - 0s 2ms/step - loss: 3.5428e-04 - accuracy: 1.0000
# Epoch 53/80
# 15/15 [==============================] - 0s 2ms/step - loss: 3.0415e-04 - accuracy: 1.0000
# Epoch 54/80
# 15/15 [==============================] - 0s 2ms/step - loss: 2.7169e-04 - accuracy: 1.0000
# Epoch 55/80
# 15/15 [==============================] - 0s 2ms/step - loss: 2.6257e-04 - accuracy: 1.0000
# Epoch 56/80
# 15/15 [==============================] - 0s 2ms/step - loss: 2.4835e-04 - accuracy: 1.0000
# Epoch 57/80
# 15/15 [==============================] - 0s 2ms/step - loss: 2.2333e-04 - accuracy: 1.0000
# Epoch 58/80
# 15/15 [==============================] - 0s 2ms/step - loss: 2.1091e-04 - accuracy: 1.0000
# Epoch 59/80
# 15/15 [==============================] - 0s 2ms/step - loss: 1.9674e-04 - accuracy: 1.0000
# Epoch 60/80
# 15/15 [==============================] - 0s 2ms/step - loss: 1.8495e-04 - accuracy: 1.0000
# Epoch 61/80
# 15/15 [==============================] - 0s 2ms/step - loss: 1.8506e-04 - accuracy: 1.0000
# Epoch 62/80
# 15/15 [==============================] - 0s 2ms/step - loss: 1.6865e-04 - accuracy: 1.0000
# Epoch 63/80
# 15/15 [==============================] - 0s 2ms/step - loss: 1.5947e-04 - accuracy: 1.0000
# Epoch 64/80
# 15/15 [==============================] - 0s 2ms/step - loss: 1.5479e-04 - accuracy: 1.0000
# Epoch 65/80
# 15/15 [==============================] - 0s 2ms/step - loss: 1.5700e-04 - accuracy: 1.0000
# Epoch 66/80
# 15/15 [==============================] - 0s 2ms/step - loss: 1.5454e-04 - accuracy: 1.0000
# Epoch 67/80
# 15/15 [==============================] - 0s 2ms/step - loss: 1.3589e-04 - accuracy: 1.0000
# Epoch 68/80
# 15/15 [==============================] - 0s 2ms/step - loss: 1.3148e-04 - accuracy: 1.0000
# Epoch 69/80
# 15/15 [==============================] - 0s 2ms/step - loss: 1.2688e-04 - accuracy: 1.0000
# Epoch 70/80
# 15/15 [==============================] - 0s 2ms/step - loss: 1.2275e-04 - accuracy: 1.0000
# Epoch 71/80
# 15/15 [==============================] - 0s 2ms/step - loss: 1.1818e-04 - accuracy: 1.0000
# Epoch 72/80
# 15/15 [==============================] - 0s 2ms/step - loss: 1.2045e-04 - accuracy: 1.0000
# Epoch 73/80
# 15/15 [==============================] - 0s 2ms/step - loss: 1.1118e-04 - accuracy: 1.0000
# Epoch 74/80
# 15/15 [==============================] - 0s 2ms/step - loss: 1.1849e-04 - accuracy: 1.0000
# Epoch 75/80
# 15/15 [==============================] - 0s 2ms/step - loss: 1.1163e-04 - accuracy: 1.0000
# Epoch 76/80
# 15/15 [==============================] - 0s 2ms/step - loss: 1.0009e-04 - accuracy: 1.0000
# Epoch 77/80
# 15/15 [==============================] - 0s 2ms/step - loss: 9.8094e-05 - accuracy: 1.0000
# Epoch 78/80
# 15/15 [==============================] - 0s 2ms/step - loss: 9.3561e-05 - accuracy: 1.0000
# Epoch 79/80
# 15/15 [==============================] - 0s 2ms/step - loss: 9.1755e-05 - accuracy: 1.0000
# Epoch 80/80
# 15/15 [==============================] - 0s 2ms/step - loss: 8.9121e-05 - accuracy: 1.0000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2258 - accuracy: 0.9649
#
# Out second neural network managed 96.49% accuracy.

# %%
# You may even want to try to split your train data to also 
# get validation data and then try to optimize the parameters of your network
