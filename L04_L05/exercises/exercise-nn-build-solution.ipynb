# %% [markdown]
# # Exercise - building neural networks using TensorFlow
#
# 1. Start by replicating the neural network in the slides (not the training - building it and using the method $\texttt{.summary}$. You can see the number of parameters in each layer. Can you relate this to the number of features, the number of hidden nodes, and the number of output nodes?
# 2. Do you believe the model has too many parameters? Too few? Try to change the number of parameters (in whichever direction you believe is best) and then train the model on the breast cancer data. Is your model better than the one in the slides? **Bonus**: try also to change the number of epochs you train for, as well as anything else you might want to experiment with.
#
# **Note**: The number of epochs is the number of times the neural network sees each observation. In the above example, each observation is shown 5 times.
#
# **See slides for more details!**

# %% [markdown]
# # Exercise 1
#
# Start by replicating the neural network in the slides (not the training - building it and using the method $\texttt{.summary}$. You can see the number of parameters in each layer. Can you relate this to the number of features, the number of hidden nodes, and the number of output nodes?

# %%
import tensorflow as tf

my_nn = tf.keras.models.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(30,)), # input shape required in the first layer
    tf.keras.layers.Dense(128, activation='relu'), # map 64 to 128 features and apply ReLU
    tf.keras.layers.Dense(2, activation='softmax'), # softmax is used for classification
    ])

my_nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                1984
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  dense_2 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 10,562
# Trainable params: 10,562
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Exercise 2
#
# Do you believe the model has too many parameters? Too few? Try to change the number of parameters (in whichever direction you believe is best) and then train the model on the breast cancer data. Is your model better than the one in the slides? **Bonus**: try also to change the number of epochs you train for, as well as anything else you might want to experiment with.

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Use the `load_breast_cancer` function to construct your dataset
x, y = load_breast_cancer(return_X_y=True)

# Use `train_test_split` to split your data into a train and a test set.
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

scaler = StandardScaler()
z_train = scaler.fit_transform(x_train)
z_test = scaler.transform(x_test)

# %%
# Build your own, new neural network here
import tensorflow as tf
first = tf.keras.models.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(30,)), # input shape required in the first layer
    tf.keras.layers.Dense(128, activation='relu'), # map 64 to 128 features and apply ReLU
    tf.keras.layers.Dense(128, activation='relu'), # map 128 to 128 features and apply ReLU
    tf.keras.layers.Dense(64, activation='relu'), # map 128 to 64 features and apply ReLU
    tf.keras.layers.Dense(2, activation='softmax'), # softmax is used for classification
    ])
first.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 64)                1984
#
#  dense_4 (Dense)             (None, 128)               8320
#
#  dense_5 (Dense)             (None, 128)               16512
#
#  dense_6 (Dense)             (None, 64)                8256
#
#  dense_7 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 35,202
# Trainable params: 35,202
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile it, train it, and evaluate it
first.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'],
    )
first.fit(z_train,y_train,epochs=5)

loss, accuracy = first.evaluate(z_test, y_test)

print(f'\nOut first neural network managed {round(accuracy * 100, 2)}% accuracy.')
# Out:
# Epoch 1/5
# 15/15 [==============================] - 0s 214us/step - loss: 0.6157 - accuracy: 0.6747
# Epoch 2/5
# 15/15 [==============================] - 0s 1000us/step - loss: 0.5321 - accuracy: 0.9077
# Epoch 3/5
# 15/15 [==============================] - 0s 1ms/step - loss: 0.4600 - accuracy: 0.9275
# Epoch 4/5
# 15/15 [==============================] - 0s 988us/step - loss: 0.3967 - accuracy: 0.9319
# Epoch 5/5
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3425 - accuracy: 0.9407
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3027 - accuracy: 0.9474
#
# Out first neural network managed 94.74% accuracy.

# %%
# And now try some other stuff, such as training for another number of epochs
first.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'],
    )
first.fit(z_train,y_train,epochs=100)

loss, accuracy = first.evaluate(z_test, y_test)

print(f'\nOut second neural network managed {round(accuracy * 100, 2)}% accuracy.')
# Out:
# Epoch 1/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.1723 - accuracy: 0.9516
# Epoch 2/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0672 - accuracy: 0.9846
# Epoch 3/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0547 - accuracy: 0.9824
# Epoch 4/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0368 - accuracy: 0.9846
# Epoch 5/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0316 - accuracy: 0.9912
# Epoch 6/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0224 - accuracy: 0.9912
# Epoch 7/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0224 - accuracy: 0.9912
# Epoch 8/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0100 - accuracy: 0.9978
# Epoch 9/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0061 - accuracy: 0.9978
# Epoch 10/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 11/100
# 15/15 [==============================] - 0s 0s/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 12/100
# 15/15 [==============================] - 0s 0s/step - loss: 0.0065 - accuracy: 0.9956
# Epoch 13/100
# 15/15 [==============================] - 0s 144us/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 14/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 15/100
# 15/15 [==============================] - 0s 1ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 16/100
# 15/15 [==============================] - 0s 1ms/step - loss: 8.3663e-04 - accuracy: 1.0000
# Epoch 17/100
# 15/15 [==============================] - 0s 1ms/step - loss: 6.9712e-04 - accuracy: 1.0000
# Epoch 18/100
# 15/15 [==============================] - 0s 1ms/step - loss: 5.4755e-04 - accuracy: 1.0000
# Epoch 19/100
# 15/15 [==============================] - 0s 1ms/step - loss: 4.4506e-04 - accuracy: 1.0000
# Epoch 20/100
# 15/15 [==============================] - 0s 1ms/step - loss: 3.9108e-04 - accuracy: 1.0000
# Epoch 21/100
# 15/15 [==============================] - 0s 0s/step - loss: 3.3062e-04 - accuracy: 1.0000
# Epoch 22/100
# 15/15 [==============================] - 0s 1ms/step - loss: 3.0269e-04 - accuracy: 1.0000
# Epoch 23/100
# 15/15 [==============================] - 0s 1ms/step - loss: 2.8383e-04 - accuracy: 1.0000
# Epoch 24/100
# 15/15 [==============================] - 0s 1ms/step - loss: 2.4013e-04 - accuracy: 1.0000
# Epoch 25/100
# 15/15 [==============================] - 0s 1ms/step - loss: 2.1437e-04 - accuracy: 1.0000
# Epoch 26/100
# 15/15 [==============================] - 0s 986us/step - loss: 1.9490e-04 - accuracy: 1.0000
# Epoch 27/100
# 15/15 [==============================] - 0s 1ms/step - loss: 1.7333e-04 - accuracy: 1.0000
# Epoch 28/100
# 15/15 [==============================] - 0s 891us/step - loss: 1.6262e-04 - accuracy: 1.0000
# Epoch 29/100
# 15/15 [==============================] - 0s 900us/step - loss: 1.4945e-04 - accuracy: 1.0000
# Epoch 30/100
# 15/15 [==============================] - 0s 0s/step - loss: 1.3732e-04 - accuracy: 1.0000
# Epoch 31/100
# 15/15 [==============================] - 0s 74us/step - loss: 1.2893e-04 - accuracy: 1.0000
# Epoch 32/100
# 15/15 [==============================] - 0s 1ms/step - loss: 1.1868e-04 - accuracy: 1.0000
# Epoch 33/100
# 15/15 [==============================] - 0s 947us/step - loss: 1.1230e-04 - accuracy: 1.0000
# Epoch 34/100
# 15/15 [==============================] - 0s 1ms/step - loss: 1
# Epoch 67/100
# 15/15 [==============================] - 0s 608us/step - loss: 2.4422e-05 - accuracy: 1.0000
# Epoch 68/100
# 15/15 [==============================] - 0s 1ms/step - loss: 2.2965e-05 - accuracy: 1.0000
# Epoch 69/100
# 15/15 [==============================] - 0s 1ms/step - loss: 2.1200e-05 - accuracy: 1.0000
# Epoch 70/100
# 15/15 [==============================] - 0s 1ms/step - loss: 2.0469e-05 - accuracy: 1.0000
# Epoch 71/100
# 15/15 [==============================] - 0s 1ms/step - loss: 1.9705e-05 - accuracy: 1.0000
# Epoch 72/100
# 15/15 [==============================] - 0s 0s/step - loss: 1.9053e-05 - accuracy: 1.0000
# Epoch 73/100
# 15/15 [==============================] - 0s 679us/step - loss: 1.8885e-05 - accuracy: 1.0000
# Epoch 74/100
# 15/15 [==============================] - 0s 138us/step - loss: 1.8147e-05 - accuracy: 1.0000
# Epoch 75/100
# 15/15 [==============================] - 0s 1ms/step - loss: 1.7475e-05 - accuracy: 1.0000
# Epoch 76/100
# 15/15 [==============================] - 0s 1ms/step - loss: 1.7017e-05 - accuracy: 1.0000
# Epoch 77/100
# 15/15 [==============================] - 0s 1ms/step - loss: 1.6602e-05 - accuracy: 1.0000
# Epoch 78/100
# 15/15 [==============================] - 0s 1ms/step - loss: 1.6022e-05 - accuracy: 1.0000
# Epoch 79/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.5634e-05 - accuracy: 1.0000
# Epoch 80/100
# 15/15 [==============================] - 0s 512us/step - loss: 1.5175e-05 - accuracy: 1.0000
# Epoch 81/100
# 15/15 [==============================] - 0s 1ms/step - loss: 1.5045e-05 - accuracy: 1.0000
# Epoch 82/100
# 15/15 [==============================] - 0s 1ms/step - loss: 1.4545e-05 - accuracy: 1.0000
# Epoch 83/100
# 15/15 [==============================] - 0s 1ms/step - loss: 1.4159e-05 - accuracy: 1.0000
# Epoch 84/100
# 15/15 [==============================] - 0s 1ms/step - loss: 1.3568e-05 - accuracy: 1.0000
# Epoch 85/100
# 15/15 [==============================] - 0s 1ms/step - loss: 1.3155e-05 - accuracy: 1.0000
# Epoch 86/100
# 15/15 [==============================] - 0s 715us/step - loss: 1.2892e-05 - accuracy: 1.0000
# Epoch 87/100
# 15/15 [==============================] - 0s 0s/step - loss: 1.2577e-05 - accuracy: 1.0000
# Epoch 88/100
# 15/15 [==============================] - 0s 903us/step - loss: 1.2287e-05 - accuracy: 1.0000
# Epoch 89/100
# 15/15 [==============================] - 0s 351us/step - loss: 1.2054e-05 - accuracy: 1.0000
# Epoch 90/100
# 15/15 [==============================] - 0s 2ms/step - loss: 1.1647e-05 - accuracy: 1.0000
# Epoch 91/100
# 15/15 [==============================] - 0s 264us/step - loss: 1.1661e-05 - accuracy: 1.0000
# Epoch 92/100
# 15/15 [==============================] - 0s 1ms/step - loss: 1.1137e-05 - accuracy: 1.0000
# Epoch 93/100
# 15/15 [==============================] - 0s 1ms/step - loss: 1.0875e-05 - accuracy: 1.0000
# Epoch 94/100
# 15/15 [==============================] - 0s 796us/step - loss: 1.0622e-05 - accuracy: 1.0000
# Epoch 95/100
# 15/15 [==============================] - 0s 907us/step - loss: 1.0446e-05 - accuracy: 1.0000
# Epoch 96/100
# 15/15 [==============================] - 0s 857us/step - loss: 1.0099e-05 - accuracy: 1.0000
# Epoch 97/100
# 15/15 [==============================] - 0s 608us/step - loss: 9.8690e-06 - accuracy: 1.0000
# Epoch 98/100
# 15/15 [==============================] - 0s 387us/step - loss: 9.6718e-06 - accuracy: 1.0000
# Epoch 99/100
# 15/15 [==============================] - 0s 901us/step - loss: 9.4403e-06 - accuracy: 1.0000
# Epoch 100/100
# 15/15 [==============================] - 0s 928us/step - loss: 9.2972e-06 - accuracy: 1.0000
# 4/4 [==============================] - 0s 735us/step - loss: 0.1636 - accuracy: 0.9737
#
# Out second neural network managed 97.37% accuracy.

# %%
# You may even want to try to split your train data to also 
# get validation data and then try to optimize the parameters of your network
