# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
from sklearn.datasets import make_circles
from matplotlib import pyplot as plt
import numpy as np

# Our data. X is (n, 2), i.e. 2 variables. y is (n,).
X, y = make_circles(n_samples=300, noise=0.01)

# Adding a new variable
z = X[:, 0] ** 2 + X[:, 1] ** 2

# %%
z
# Out:
# array([1.03514745, 1.0042794 , 1.02744551, 0.64775966, 0.64627158,
#        0.95153745, 1.00731892, 1.01046008, 0.63369623, 0.61328142,
#        0.99717595, 0.62521087, 1.01885209, 0.63922345, 1.00009076,
#        1.02129783, 1.0035052 , 0.98455598, 0.68097194, 0.64723231,
#        0.63158169, 0.99909593, 0.97473672, 1.02614452, 1.01179601,
#        0.98648473, 0.99993636, 0.62025343, 0.65071518, 0.65574595,
#        0.60295914, 0.99107131, 0.99146328, 1.00790949, 0.61818962,
#        0.66996528, 0.61710604, 0.68897054, 0.99396619, 0.95473409,
#        0.62366788, 1.03238903, 0.64782882, 0.60153864, 0.63229044,
#        1.0074506 , 0.66329352, 0.99200428, 0.99199425, 0.63647911,
#        0.97663625, 0.64177506, 0.64942293, 1.03892013, 0.62676556,
#        0.6603571 , 0.98927468, 0.65722288, 0.99246412, 0.63136437,
#        0.99228949, 0.9694083 , 0.62220048, 0.9899838 , 0.99438042,
#        0.63330873, 0.63004946, 0.61677051, 0.65797395, 0.60385556,
# ...

# %%
X
# Out:
# array([[ 0.68657296, -0.75084287],
#        [-1.0018973 , -0.02193607],
#        [ 0.19335889, -0.99501651],
#        [ 0.66622716,  0.45155403],
#        [-0.73429632, -0.32723156],
#        [-0.8306552 ,  0.511419  ],
#        [ 0.48876741,  0.87659873],
#        [ 0.84020278, -0.55183273],
#        [ 0.27936688, -0.7454196 ],
#        [ 0.2109711 ,  0.75417015],
#        [ 0.91350011,  0.40335283],
#        [ 0.64090001,  0.46309615],
#        [ 1.00341535,  0.10958887],
#        [ 0.40843269,  0.68731812],
#        [-0.54395701, -0.83916717],
#        [ 0.84564562,  0.55333653],
#        [ 0.99382974, -0.1257285 ],
#        [-0.06996237, -0.98977839],
#        [-0.24094446,  0.78925136],
#        [-0.61223709,  0.52191767],
#        [ 0.17992425,  0.77408588],
#        [-0.24289442,  0.96958663],
#        [ 0.68451513,  0.71146029],
#        [ 0.77205621, -0.65580006],
#        [ 0.25645302,  0.97263964],
#        [-0.49584405, -0.8605948 ],
#        [-0.61291325, -0.79010994],
# ...

# %%
type(z)
# Out:
# numpy.ndarray

# %% [markdown]
# ## Things we can do for betterment

# %% [markdown]
# 1. To demonstrate the prediction, we can create an array containing the predicted result and test result side by side (showed in A-Z)
# 2. We can show confusion matrix with custom label (showed in statquest)
# 3. We can print the accuracy score (showed in lecture)
# 4. We can show the test result (test set of X) in a scatter plot of truth and the model (showed in lecture)
# 5. We can visualize the whole SVM of training and test set
# 6. Apply cross validation for parameter tuning
# 7. Apply scaling and centering
# 8. Apply additional feature eng technique (need to explore more on this)
